# %%
import DSM as dsm

t = 1.0
y = 1.0
a = 1.0
b = 1.0
cs = 1.0
cl = 1.0
qs = 1.0
k = 1.0
r = 1.0
eps = 1.0
m = 1.0
gc = 1.0
nl = 1.0
A = dsm.adverse_load()
Ts = 1.0
Tl = 1.0

dsm.ode(t, y, a, b, cs, cl, qs, k, r, eps, m, gc, nl, A, Ts, Tl)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 20
#      16 A = 1.0
#      17 Ts = 1.0
#      18 Tl = 1.0
#      19
# ---> 20 dsm.ode(t, y, a, b, cs, cl, qs, k, r, eps, m, gc, nl, A, Ts, Tl)
#
# File ~/Dev/mpi26-vironix/src/DSM.py:47, in ode(t, y, a, b, cs, cl, qs, k, r, eps, m, gc, nl, A, Ts, Tl)
#      46 def ode(t, y, a, b, cs, cl, qs, k, r, eps, m, gc, nl, A, Ts, Tl):
# ---> 47     x = y[0]
#      48     g = y[1]
#      49     d = y[2]
#
# TypeError: 'float' object is not subscriptable
